# %%
# Calculate the mean of a numeric vector
numbers <- c(1, 2, 3, 4, 5)
mean(numbers)
# Out:
# [1] 3

# %%
install.packages("ggplot2", lib = '/workspaces/codespaces-jupyter/notebooks')
# Out:
# also installing the dependencies 'colorspace', 'farver', 'labeling', 'munsell', 'R6', 'RColorBrewer', 'viridisLite', 'magrittr', 'pkgconfig', 'gtable', 'isoband', 'scales', 'tibble', 'withr'

# %%
install.packages("withr", lib = '/workspaces/codespaces-jupyter/notebooks')

# %%
install.packages("withr", lib = '/workspaces/codespaces-jupyter/notebooks')

# %%
library(withr, lib.loc = '/workspaces/codespaces-jupyter/notebooks')
library(ggplot2, lib.loc = '/workspaces/codespaces-jupyter/notebooks')
library(dplyr, lib.loc = '/workspaces/codespaces-jupyter/notebooks')
library(labeling, lib.loc = '/workspaces/codespaces-jupyter/notebooks')
library(farver, lib.loc = '/workspaces/codespaces-jupyter/notebooks')

x <- rnorm(100)
y <- rnorm(100)
ggplot(data.frame(x, y), aes(x, y)) + geom_point()
# Out:
# plot without title

# %%
set.seed(123)
x <- rnorm(50, mean = 5, sd = 2)
y <- rnorm(50, mean = 8, sd = 3)
df <- data.frame(x, y)
ggplot(df, aes(x, y)) + geom_point() + ggtitle("Scatter plot of x and y") + xlab("x") + ylab("y")
# Out:
# plot without title
